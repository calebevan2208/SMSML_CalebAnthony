# %% [markdown]
# # SMSML CalebAnthony Project - Google Colab
#
# Notebook ini dirancang untuk menjalankan pipeline Machine Learning end-to-end untuk prediksi Churn Nasabah.
#
# **Fitur:**
# 1.  Data Ingestion & Cleaning Otomatis
# 2.  Exploratory Data Analysis (EDA)
# 3.  Baseline Modeling (TensorFlow)
# 4.  Hyperparameter Tuning dengan Tracking MLflow ke DagsHub

# %% [markdown]
# ## 1. Setup Environment
# Langkah ini akan menginstall semua library yang dibutuhkan.

# %%
# Clone repository (Jika belum ada)
# !git clone https://github.com/iamikhsank/SMSML_CalebAnthony.git
# %cd SMSML_CalebAnthony

# Install Dependencies
# !pip install -r SMSML_CalebAnthony/Membangun_model/requirements.txt
# !pip install dagshub
# Out:
# Cloning into 'SMSML_CalebAnthony'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'SMSML_CalebAnthony'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'SMSML_CalebAnthony/Membangun_model/requirements.txt'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 82.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony
# Out:
# /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony

# %%
# Install Dependencies
# !pip install -r Membangun_model/requirements.txt
# !pip install dagshub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.7/774.7 kB 44.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.4
#     Uninstalling cachetools-6.2.4:
#       Successfully uninstalled cachetools-6.2.4
# ...

# %%
# !ls
# Out:
# Eksperimen_SML_CalebAnthony  README.md			     Workflow-CI
# Membangun_model		     SMSML_CalebAnthony_Colab.ipynb

# %% [markdown]
# ## 2. Data Automation
# Mengunduh data dari Google Sheets dan membersihkannya.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python Eksperimen_SML_CalebAnthony/automate_CalebAnthony.py
# Out:
# 2025-12-19 17:12:02 - INFO - === START PIPELINE AUTOMATION ===
# 2025-12-19 17:12:02 - INFO - Memulai proses Ingestion Data...
# 2025-12-19 17:12:02 - WARNING - File lokal tidak ditemukan. Mencoba mengunduh dari remote source...
# 2025-12-19 17:12:08 - INFO - Unduhan berhasil. Raw data disimpan di: /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony/Eksperimen_SML_CalebAnthony/churn_raw/data.csv
# 2025-12-19 17:12:08 - INFO - Memulai proses Preprocessing Data...
# 2025-12-19 17:12:08 - INFO - Menstandarisasi nama kolom...
# 2025-12-19 17:12:08 - INFO - Kolom 'PAY_0' diubah menjadi 'PAY_1'.
# 2025-12-19 17:12:08 - INFO - Kolom 'ID' dihapus karena tidak relevan untuk pemodelan.
# 2025-12-19 17:12:08 - INFO - Memproses encoding kolom: SEX
# 2025-12-19 17:12:08 - INFO - Memproses encoding kolom: EDUCATION
# 2025-12-19 17:12:08 - INFO - Memproses encoding kolom: MARRIAGE
# 2025-12-19 17:12:08 - INFO - Memproses encoding kolom: default
# ...

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
# Menghasilkan visualisasi statistik data.

# %%
# !python Eksperimen_SML_CalebAnthony/eksperimen_CalebAnthony.py
# Out:
# 2025-12-19 17:13:31 - INFO - Advanced EDA initialized. Output path: /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony/Eksperimen_SML_CalebAnthony/analysis_results
# 2025-12-19 17:13:31 - INFO - === STARTING ADVANCED EDA ===
# 2025-12-19 17:13:31 - INFO - Data dimuat: (30000, 25)
# 2025-12-19 17:13:32 - INFO - Statistik deskriptif tersimpan.
# /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony/Eksperimen_SML_CalebAnthony/eksperimen_CalebAnthony.py:107: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Label', data=self.df, palette=['#2ecc71', '#e74c3c'], order=['Non-Churn', 'Churn'])
# 2025-12-19 17:13:32 - INFO - [Plot 1] Target distribution saved.
# 2025-12-19 17:13:32 - INFO - Menghitung korelasi fitur...
# 2025-12-19 17:13:33 - INFO - [Plot 2] Feature correlation ranking saved.
# ...

# %% [markdown]
# ## 4. Baseline Modeling
# Melatih model Deep Learning dasar.

# %%
# !python Membangun_model/modelling.py
# Out:
# 2025-12-19 17:15:43.190389: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:15:43.695263: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:15:43.988387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766164544.297524    7766 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766164544.313383    7766 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## 5. Hyperparameter Tuning (MLflow + DagsHub)
# Menjalankan tuning dan mengirim hasil eksperimen ke DagsHub.
#
# **Note:** Pastikan script `modelling_tuning.py` sudah dikonfigurasi dengan repo owner dan name yang benar, atau DagsHub akan meminta autentikasi interaktif.

# %%
# !python Membangun_model/modelling_tuning.py
# Out:
# 2025-12-19 17:17:44.280834: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:17:44.286047: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-19 17:17:44.300256: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766164664.325365    8704 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766164664.332610    8704 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Client/run-smsml-pipeline/SMSML_CalebAnthony/.git/

# %%
! git add
